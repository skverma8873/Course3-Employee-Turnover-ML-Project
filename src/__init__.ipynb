# %% [markdown]
# #   Init
#
# **File:** `src\__init__.py`
#
# Employee Turnover Analytics — ML Pipeline Package
#
# Version: 1.0.0

# %% [markdown]
# ### Imports & Module-Level Constants
#
# All dependencies and configuration constants used throughout this module are loaded here.

# %%
__version__ = "1.0.0"
__author__ = "Portobello Tech HR Analytics Team"
